# %%
import pandas as pd
import numpy as np

# %%
rna_str = '...'

# %%
dupl_50_1643 = pd.read_csv('~/Desktop/duplexes_50_1643.csv', sep = ' ', header = None, dtype = {0:'Int64', 1:'Int64', 2: 'float', 3: 'string'})
dupl_70_1643 = pd.read_csv('~/Desktop/duplexes_70_1643.csv', sep = ' ', header = None, dtype = {0:'Int64', 1:'Int64', 2: 'float', 3: 'string'})
dupl_90_1643 = pd.read_csv('~/Desktop/duplexes_90_1643.csv', sep = ' ', header = None, dtype = {0:'Int64', 1:'Int64', 2: 'float', 3: 'string'})
dupl_50 = pd.read_csv('~/Desktop/duplexes_50.csv', sep = ' ', header = None, dtype = {0:'Int64', 1:'Int64', 2: 'float', 3: 'string'})
dupl_70 = pd.read_csv('~/Desktop/duplexes_70.csv', sep = ' ', header = None, dtype = {0:'Int64', 1:'Int64', 2: 'float', 3: 'string'})
dupl_90 = pd.read_csv('~/Desktop/duplexes_90.csv', sep = ' ', header = None, dtype = {0:'Int64', 1:'Int64', 2: 'float', 3: 'string'})

# %%
rna_list = []
for i in rna_str:
    rna_list.append(i)
for i in dupl_90[0]:
    rna_list[i-1]='N'
for i in dupl_90[1]:
    rna_list[i-1]='N'
''.join(rna_list)
# Out:
# '...'

# %%
rna_list = []
for i in rna_str:
    rna_list.append(i)
for i in dupl_70[0]:
    rna_list[i-1]='N'
for i in dupl_70[1]:
    rna_list[i-1]='N'
''.join(rna_list)
# Out:
# '...'

# %%
rna_list = []
for i in rna_str:
    rna_list.append(i)
for i in dupl_50[0]:
    rna_list[i-1]='N'
for i in dupl_50[1]:
    rna_list[i-1]='N'
''.join(rna_list)
# Out:
# '...'
